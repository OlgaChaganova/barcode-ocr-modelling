# %%
import sys
sys.path.append('../src')

import cv2
import matplotlib.pyplot as plt
from omegaconf import OmegaConf

from ocr import OCRecogniser

# %%
config = OmegaConf.load('../configs/ocr.yml')
config
# Out:
# {'model_path': '/home/olik/edu/cvr-hw2-ocr/weights/epoch=320-step=963.onnx', 'blank': 10, 'img_height': 128, 'img_width': 512}

# %%
ocr_model = OCRecogniser(config=config)

# %%
image = cv2.imread('/home/olik/edu/cvr-hw2-ocr/data/barcodes-annotated-gorai_detected/images/0a0de03b-710c-40e4-8f0e-5fa0ee9ef0a5--ru.b7135dcc-0514-43de-a53d-87f41aae71e4.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
ocr_model.predict(image[None])
# Out:
# ['1']
